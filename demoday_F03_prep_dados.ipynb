# %% [markdown]
# # FASE 3 - AMBIENTE E PREPARAÇÃO DOS DADOS
# O objetivo desta fase é realizar a leitura, join e limpeza dos dados

# %%
# importação dos pacotes
import numpy as np # vetores
import pandas as pd # estrutura e análise de dados
import matplotlib as plt # visualização dos dados
import datetime as dt # tratamento de data e horário

import pandas as pd
import os
from sklearn import preprocessing
import time
seconds = time.time()
# %matplotlib inline

# %% [markdown]
# ## Importar dataset
# - Leitura dos arquivos seledionados

# %%
# Leitura de arquivos sendo realizada separadamente, sendo identificado erro no df4
df1 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Monday-WorkingHours.pcap_ISCX.csv")

# %%
df1.head()
# Out:
#                                   Flow ID      Source IP   Source Port  \
# 0   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 1   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 2   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 3   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 4  192.168.10.14-8.253.185.121-49486-80-6  8.253.185.121            80
#
#    Destination IP   Destination Port   Protocol            Timestamp  \
# 0    192.168.10.5              49188          6  03/07/2017 08:55:58
# 1    192.168.10.5              49188          6  03/07/2017 08:55:58
# 2    192.168.10.5              49188          6  03/07/2017 08:55:58
# 3    192.168.10.5              49188          6  03/07/2017 08:55:58
# 4   192.168.10.14              49486          6  03/07/2017 08:56:22
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Tuesday-WorkingHours.pcap_ISCX.csv")

# %%
df3 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Wednesday-workingHours.pcap_ISCX.csv")

# %%
#df4 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
#UnicodeDecodeError: 'utf-8' codec can't decode byte 0x96 in position 22398: invalid start byte

# %%
df5 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")

# %%
df6 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Friday-WorkingHours-Morning.pcap_ISCX.csv")

# %%
df7 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")

# %%
df8 = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")

# %%
# Concatenar os arquivos
df=pd.concat([df1,df2,df3,df5,df6,df7,df8])

# %%
df.head()
# Out:
#                                   Flow ID      Source IP   Source Port  \
# 0   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 1   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 2   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 3   192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126            80
# 4  192.168.10.14-8.253.185.121-49486-80-6  8.253.185.121            80
#
#    Destination IP   Destination Port   Protocol            Timestamp  \
# 0    192.168.10.5              49188          6  03/07/2017 08:55:58
# 1    192.168.10.5              49188          6  03/07/2017 08:55:58
# 2    192.168.10.5              49188          6  03/07/2017 08:55:58
# 3    192.168.10.5              49188          6  03/07/2017 08:55:58
# 4   192.168.10.14              49486          6  03/07/2017 08:56:22
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# ...

# %%
# AGrupa por Label
df.groupby(' Label').first()
# Out:
#                                                   Flow ID      Source IP  \
#  Label
# BENIGN              192.168.10.5-8.254.250.126-49188-80-6  8.254.250.126
# Bot                 192.168.10.12-52.6.13.28-42544-8080-6  192.168.10.12
# DDoS                  172.16.0.1-192.168.10.50-49650-80-6     172.16.0.1
# DoS GoldenEye         172.16.0.1-192.168.10.50-58958-80-6     172.16.0.1
# DoS Hulk              172.16.0.1-192.168.10.50-50748-80-6     172.16.0.1
# DoS Slowhttptest      172.16.0.1-192.168.10.50-33372-80-6     172.16.0.1
# DoS slowloris         172.16.0.1-192.168.10.50-49631-80-6     172.16.0.1
# FTP-Patator           172.16.0.1-192.168.10.50-45422-80-6     172.16.0.1
# Heartbleed           172.16.0.1-192.168.10.51-45022-444-6     172.16.0.1
# Infiltration      192.168.10.8-205.174.165.73-53966-444-6   192.168.10.8
# PortScan              172.16.0.1-192.168.10.50-40620-80-6     172.16.0.1
# SSH-Patator           172.16.0.1-192.168.10.50-52358-22-6     172.16.0.1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2660377 entries, 0 to 225744
# Data columns (total 85 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Flow ID                       object
#  1    Source IP                    object
#  2    Source Port                  int64
#  3    Destination IP               object
#  4    Destination Port             int64
#  5    Protocol                     int64
#  6    Timestamp                    object
#  7    Flow Duration                int64
#  8    Total Fwd Packets            int64
#  9    Total Backward Packets       int64
#  10  Total Length of Fwd Packets   float64
#  11   Total Length of Bwd Packets  float64
#  12   Fwd Packet Length Max        float64
#  13   Fwd Packet Length Min        float64
#  14   Fwd Packet Length Mean       float64
#  15   Fwd Packet Length Std        float64
#  16  Bwd Packet Length Max         float64
#  17   Bwd Packet Length Min        float64
# ...

# %%
df.describe()
# Out:
#         Source Port   Destination Port      Protocol   Flow Duration  \
# count  2.660377e+06       2.660377e+06  2.660377e+06    2.660377e+06
# mean   4.119086e+04       8.082650e+03  9.791050e+00    1.493437e+07
# std    2.219059e+04       1.828666e+04  5.233462e+00    3.375518e+07
# min    0.000000e+00       0.000000e+00  0.000000e+00   -1.300000e+01
# 25%    3.297500e+04       5.300000e+01  6.000000e+00    1.510000e+02
# 50%    5.094500e+04       8.000000e+01  6.000000e+00    3.131000e+04
# 75%    5.833100e+04       4.430000e+02  1.700000e+01    3.392684e+06
# max    6.553500e+04       6.553500e+04  1.700000e+01    1.200000e+08
#
#         Total Fwd Packets   Total Backward Packets  \
# count        2.660377e+06             2.660377e+06
# mean         8.992078e+00             9.905254e+00
# std          7.191812e+02             9.567938e+02
# min          1.000000e+00             0.000000e+00
# 25%          2.000000e+00             1.000000e+00
# ...

# %%
df.columns
# Out:
# Index(['Flow ID', ' Source IP', ' Source Port', ' Destination IP',
#        ' Destination Port', ' Protocol', ' Timestamp', ' Flow Duration',
#        ' Total Fwd Packets', ' Total Backward Packets',
#        'Total Length of Fwd Packets', ' Total Length of Bwd Packets',
#        ' Fwd Packet Length Max', ' Fwd Packet Length Min',
#        ' Fwd Packet Length Mean', ' Fwd Packet Length Std',
#        'Bwd Packet Length Max', ' Bwd Packet Length Min',
#        ' Bwd Packet Length Mean', ' Bwd Packet Length Std', 'Flow Bytes/s',
#        ' Flow Packets/s', ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max',
#        ' Flow IAT Min', 'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std',
#        ' Fwd IAT Max', ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean',
#        ' Bwd IAT Std', ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags',
#        ' Bwd PSH Flags', ' Fwd URG Flags', ' Bwd URG Flags',
#        ' Fwd Header Length', ' Bwd Header Length', 'Fwd Packets/s',
# ...

# %%
# Verificar os valores nulos por coluna
contagem_valores_nulos = df.isnull().sum()
# Exivir valores nulos de todas as colunas
contagem_valores_nulos[:]
# Out:
# Flow ID              0
#  Source IP           0
#  Source Port         0
#  Destination IP      0
#  Destination Port    0
#                     ..
# Idle Mean            0
#  Idle Std            0
#  Idle Max            0
#  Idle Min            0
#  Label               0
# Length: 85, dtype: int64
