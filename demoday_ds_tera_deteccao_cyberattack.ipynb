# %% [markdown]
# # FASE 1 - SOBRE O PROJETO - DEMODAY
#
# ## 1.1 Tema - Ataques Hackers
#
# Ataques de hackers tem sido cada vez mais comuns e as consequências podem ser irreparáveis para um negócio.
# Uma pesquisa realizada pela Grant Thornton com mais de 2.500 gerentes de empresas, em um período de 12 meses, companhias perderam US$ 280 bilhões por conta de ataques cibernéticos.<br>
# Os tipos de ataque mais comuns estão listados no [link](https://www.strongsecurity.com.br/blog/conheca-os-ataques-hackers-mais-comuns-e-saiba-como-se-proteger
#
# ## 1.2 Tarefa de Negócio
# Criar um modelo de Detecção e Prevenção de intrusos contra os sofisticados e crescentes "Network attacks".

# %% [markdown]
# ## 1.3 Objetivos
#
#
# ## 1.4 Entregáveis
#
# ## 1.5 Stakeholders
# 1.5.1 - Prof. Felipe Fábio Frigeri
#
# ## 1.6 Grupo de alunos - DS Tera - Turma dscbc_rem_2022_05
# 1.6.1 - Omar Luiz Cardoso de Mello Silva
# 1.6.2 - Bruno Fugita
# 1.6.3 - Yuri Longaray Pereira
# 1.6.4 - Eric Marques

# %% [markdown]
# # FASE 2 - PREPARAÇÃO DAS FONTES DE DADOS
# ## 2.1 - Informações da fonte de dados
# 2.1.1 - Os dados estão publicados em:[Canadian Institute for Cybersecurity](https://www.unb.ca/cic/datasets/ids-2017.html) armazenados em 16 arquivos csv.<br>
# 2.1.2 - Inclui nos dados coletados os registros por tipo de ataque e dia da semana.
#     -
#
# ## 2.2 -  Viés (limitações do dataset)
#
# ## 2.3 - Dados selecionados e copiados para análise

# %% [markdown]
# # FASE 3 - AMBIENTE E PREPARAÇÃO DOS DADOS
# Devido ao tamanho da base, para otimizar o processamento, esta fase será feita em outro código demoday_01_prep_dados

# %%
# importação dos pacotes
import numpy as np # vetores
import pandas as pd # estrutura e análise de dados
import matplotlib as plt # visualização dos dados
import datetime as dt # tratamento de data e horário

# %% [markdown]
# ## Importar dataset
# - Leitura dos arquivos seledionados

# %%
# read_csv método para ler os arquivos requeridos
friday_ddos = pd.read_csv(r"C:\Users\HP\Desktop\2022\tera\DESAFIOS\demoday\2017\TrafficLabelling/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")

# %%
friday_ddos.head()
# Out:
#                                    Flow ID       Source IP   Source Port  \
# 0  192.168.10.5-104.16.207.165-54865-443-6  104.16.207.165           443
# 1    192.168.10.5-104.16.28.216-55054-80-6   104.16.28.216            80
# 2    192.168.10.5-104.16.28.216-55055-80-6   104.16.28.216            80
# 3  192.168.10.16-104.17.241.25-46236-443-6   104.17.241.25           443
# 4  192.168.10.5-104.19.196.102-54863-443-6  104.19.196.102           443
#
#    Destination IP   Destination Port   Protocol      Timestamp  \
# 0    192.168.10.5              54865          6  7/7/2017 3:30
# 1    192.168.10.5              55054          6  7/7/2017 3:30
# 2    192.168.10.5              55055          6  7/7/2017 3:30
# 3   192.168.10.16              46236          6  7/7/2017 3:30
# 4    192.168.10.5              54863          6  7/7/2017 3:30
#
#     Flow Duration   Total Fwd Packets   Total Backward Packets  ...  \
# 0               3                   2                        0  ...
# ...
